# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1=cv2.imread('images/manzara.jpg')
img2=cv2.imread('images/warning.jpg')

# %%
img1_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2_rgb=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1_rgb)

# %%
plt.imshow(img2_rgb)

# %%
img1_rgb.shape
# Out:
# (410, 728, 3)

# %%
img2_rgb.shape
# Out:
# (587, 1023, 3)

# %%
img1_rgb= cv2.resize(img1_rgb,(1200,1200))
img2_rgb=cv2.resize(img2_rgb,(1200,1200))

# %%
plt.imshow(img1_rgb)

# %%
plt.imshow(img2_rgb)

# %%
blended=cv2.addWeighted(img1_rgb,0.5,img2_rgb,0.5,0)
plt.imshow(blended)

# %%
img1=cv2.imread('images/manzara.jpg')
img2=cv2.imread('images/warning.jpg')
img1_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2_rgb=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img2_rgb=cv2.resize(img2_rgb,(200,200))

# %%
large_img=img1_rgb
small_img=img2_rgb

# %%
large_img[0:200,0:200]= small_img
plt.imshow(large_img)

# %%
img1=cv2.imread('images/manzara.jpg')
img2=cv2.imread('images/warning.jpg')
img1_rgb=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2_rgb=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img2_rgb=cv2.resize(img2_rgb,(200,200))

# %%
plt.imshow(img1_rgb)

# %%
plt.imshow(img2_rgb)

# %%
img1_rgb.shape
# Out:
# (410, 728, 3)

# %%
img2_rgb.shape
# Out:
# (200, 200, 3)

# %%
roi= img1_rgb[0:410,200:728]
plt.imshow(roi)

# %%
img2gray=cv2.cvtColor(img2_rgb,cv2.COLOR_RGB2GRAY)
plt.imshow(img2gray,cmap='gray')

# %%
mask_inv=cv2.bitwise_not(img2gray)
plt.imshow(mask_inv,cmap='gray')

# %%
import numpy as np

# %%
white_background=np.full((300,300,3),255,dtype=np.uint8)

# %%
white_background.shape
# Out:
# (300, 300, 3)

# %%
mask_inv = cv2.resize(mask_inv, (white_background.shape[1], white_background.shape[0]))
bk=cv2.bitwise_or(white_background,white_background,mask=mask_inv)
plt.imshow(bk)

# %%
mask_inv=cv2.resize(mask_inv,(300,300))

# %%
mask_inv.dtype
# Out:
# dtype('uint8')

# %%
white_background.dtype
# Out:
# dtype('uint8')

# %%
roi= img1_rgb[110:410,428:728]
fg= cv2.bitwise_or(img2_rgb,img2_rgb,mask=mask_inv)
plt.imshow(fg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[114], line 2
#       1 roi= img1_rgb[110:410,428:728]
# ----> 2 fg= cv2.bitwise_or(img2_rgb,img2_rgb,mask=mask_inv)
#       3 plt.imshow(fg)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:230: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'cv::binary_op'
